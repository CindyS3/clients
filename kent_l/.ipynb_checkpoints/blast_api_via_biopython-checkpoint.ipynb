# %%
#These are the installs necessary to run the code.
#!pip install sierrapy
#!pip install biopython

#Other imports
# %pylab inline
import pandas as pd
from Bio.Blast import NCBIWWW
from Bio.Blast import NCBIXML
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
'''These functions make writing the necessary files much faster.'''

def write_fasta(f_name,seq,ID=''):
    with open(f_name+'.txt', "w") as out_handle:
        out_handle.write('>{}\n'.format(ID))
        out_handle.write(str(seq))
        
def write_fasta_multi(f_name,seqs,ID='unk'):
    with open(f_name+'.txt', "w") as out_handle:
        for seq in seqs:
            out_handle.write('>{}\n'.format(ID))
            out_handle.write(str(seq)+'\n')

def blast(f_name):
    #Read the FASTA file
    fasta_string = open(f_name+'.txt').read()
    print('Searching {}'.format(f_name)) #Progress marker
    #Submit FASTA file to BLASTn, store results
    result_handle = NCBIWWW.qblast("blastn", "nt", fasta_string)
    print('Done! Writing:') #Progress marker
    #Write the result as xml for parsing
    with open(f_name+".xml", "w") as out_handle:
         out_handle.write(result_handle.read())
    result_handle.close()
    print('Returning result for {}'.format(f_name))
    
    #Open resulting xml file
    result_handle = open(f_name+".xml")
    #Parse and store as blast record.
    blast_record = NCBIXML.read(result_handle)
    return blast_record

# %%
#First, read in the data.
data = pd.concat([pd.read_csv('training_data.csv'),pd.read_csv('test_data.csv')])
data = data[data['Resp']!=1].dropna(how='any')
#Isolate the data you want.
pr_zeros = data['PR Seq']
rt_zeros = data['RT Seq']
#Write all the sequences to fasta for manual blasting.
write_fasta_multi('files/pr_fasta',pr_zeros)
write_fasta_multi('files/rt_fasta',rt_zeros)

# %%
#This will go through every sequence,
#BLAST it,
#Grab the top hit,
#Transform the result into another fasta file,
#and finally, submit it to Sierrapy to get the stanford results.


for i,seq in enumerate(rt_zeros):
    try:
        #This creates a directory with the sequence index as it's title
        #Keeps the data organized.
        # !mkdir files/rt/{i} 
        #Use string interpolation (the {} thing) to define generic output filename
        f_name = 'files/rt/{}/{}_seq'.format(i,i)
        ID = 'unk'
        #Make a new FASTA file, this time identified - 
        #We'll submit that to sierrapy
        write_fasta(f_name+'id',seq,ID=ID)
        #Submit to sierrapy for results! -o specifies we want to store the result.
        # !sierrapy fasta {f_name+'id.txt'} -o {f_name+'id.json'}
    except: 
        pass
# Out:
# 20it [00:01, 18.52it/s]
# 20it [00:00, 20.36it/s]
# 20it [00:00, 20.34it/s]
# 20it [00:01, 17.19it/s]
# 20it [00:01, 19.79it/s]
# 20it [00:00, 20.20it/s]
# 20it [00:01, 19.69it/s]
# 20it [00:00, 20.47it/s]
# 20it [00:00, 20.35it/s]
# 20it [00:01, 19.87it/s]
# 20it [00:00, 20.18it/s]
# 20it [00:01, 17.65it/s]
# 20it [00:01, 18.07it/s]
# 20it [00:01, 17.96it/s]
# 20it [00:00, 20.05it/s]
# 20it [00:01, 19.88it/s]
# 20it [00:00, 20.53it/s]
# 20it [00:01, 19.59it/s]
# 20it [00:01, 17.91it/s]
# 20it [00:00, 20.18it/s]
# 20it [00:00, 20.60it/s]
# 20it [00:01, 19.47it/s]
# 20it [00:01, 19.70it/s]
# 20it [00:00, 20.84it/s]
# 20it [00:01, 19.28it/s]
# 20it [00:00, 20.12it/s]
# 20it [00:01, 18.10it/s]
# 20it [00:01, 19.43it/s]
# 20it [00:01, 18.01it/s]
# 20it [00:01, 19.93it/s]
# 20it [00:00, 20.14it/s]
# 20it [00:01, 18.53it/s]
# 20it [00:01, 19.53it/s]
# 20it [00:00, 20.65it/s]
# 20it [00:00, 20.78it/s]
# 20it [00:00, 20.03it/s]
# 20it [00:00, 20.35it/s]
# 20it [00:01, 19.81it/s]
# 20it [00:01, 19.76it/s]
# 20it [00:00, 20.59it/s]
# 20it [00:00, 20.20it/s]
# 20it [00:01, 17.67it/s]
# 20it [00:00, 20.92it/s]
# 20it [00:00, 20.63it/s]
# 20it [00:01, 19.65it/s]
# 20it [00:01, 19.26it/s]
# 20it [00:00, 20.10it/s]
# 20it [00:01, 18.12it/s]
# 20it [00:01, 19.98it/s]
# 20it [00:00, 20.17it/s]
# 20it [00:00, 20.95it/s]
# 20it [00:01, 19.83it/s]
# 20it [00:00, 20.85it/s]
# 20it [00:01, 19.41it/s]
# 20it [00:00, 20.90it/s]
# 20it [00:00, 20.19it/s]
# 20it [00:00, 20.61it/s]
# 20it [00:00, 20.39it/s]
# 20it [00:00, 20.72it/s]
# 20it [00:00, 20.74it/s]
# 20it [00:00, 20.18it/s]
# 20it [00:00, 21.07it/s]
# 20it [00:00, 20.07it/s]
# 20it [00:01, 19.81it/s]
# 20it [00:00, 20.17it/s]
# 20it [00:00, 20.14it/s]
# 20it [00:00, 20.40it/s]
# 20it [00:01, 19.64it/s]
# 20it [00:00, 20.05it/s]
# 20it [00:00, 20.16it/s]
# 20it [00:00, 20.20it/s]
# 20it [00:01, 19.52it/s]
# 20it [00:00, 20.44it/s]
# 20it [00:00, 20.75it/s]
# 20it [00:00, 20.24it/s]
# 20it [00:01, 19.81it/s]
# 20it [00:00, 20.19it/s]
# 20it [00:01, 19.22it/s]
# 20it [00:00, 20.04it/s]
# 20it [00:01, 19.37it/s]
# 20it [00:00, 20.76it/s]
# 20it [00:01, 19.99it/s]
# 20it [00:00, 20.60it/s]
# 20it [00:01, 19.98it/s]
# 20it [00:01, 19.81it/s]
# 20it [00:01, 18.59it/s]
# 20it [00:00, 20.13it/s]
# 20it [00:01, 19.74it/s]
# 20it [00:01, 19.99it/s]
# 20it [00:01, 19.93it/s]
# 20it [00:01, 19.73it/s]
# 20it [00:01, 19.90it/s]
# 20it [00:01, 19.56it/s]
# 20it [00:01, 16.93it/s]
# 20it [00:00, 20.38it/s]
# 20it [00:01, 19.67it/s]
# 20it [00:00, 20.10it/s]
# 20it [00:00, 20.23it/s]
# 20it [00:01, 17.55it/s]
# 20it [00:01, 19.05it/s]
# 20it [00:01, 19.84it/s]
# 20it [00:00, 20.45it/s]
# 20it [00:00, 20.40it/s]
# 20it [00:01, 19.60it/s]
# 20it [00:00, 20.16it/s]
# 20it [00:01, 19.69it/s]
# 20it [00:00, 20.25it/s]
# 20it [00:00, 20.31it/s]
# 20it [00:01, 19.62it/s]
# 20it [00:00, 20.62it/s]
# 20it [00:00, 20.45it/s]
# 20it [00:00, 20.31it/s]
# 20it [00:01, 19.39it/s]
# 20it [00:00, 20.36it/s]
# 20it [00:00, 20.25it/s]
# 20it [00:01, 19.95it/s]
# 20it [00:01, 19.72it/s]
# 20it [00:00, 20.70it/s]
# 20it [00:00, 20.32it/s]
# 20it [00:00, 21.16it/s]
# 20it [00:00, 20.20it/s]
# 20it [00:01, 19.57it/s]
# 20it [00:01, 19.81it/s]
# 20it [00:01, 19.82it/s]
# 20it [00:01, 18.87it/s]
# 20it [00:01, 19.88it/s]
# 20it [00:00, 20.50it/s]
# 20it [00:00, 20.00it/s]
# 20it [00:00, 20.12it/s]
# 20it [00:01, 19.55it/s]
# 20it [00:01, 19.96it/s]
# 20it [00:01, 19.46it/s]
# 20it [00:00, 20.18it/s]
# 20it [00:01, 19.32it/s]
# 20it [00:01, 19.74it/s]
# 20it [00:00, 20.94it/s]
# 20it [00:00, 20.50it/s]
# 20it [00:01, 19.61it/s]
# 20it [00:01, 19.62it/s]
# 20it [00:00, 20.86it/s]
# 20it [00:01, 18.03it/s]
# 20it [00:00, 20.53it/s]
# 20it [00:01, 19.29it/s]
# 20it [00:00, 21.19it/s]
# 20it [00:00, 20.04it/s]
# 20it [00:01, 19.94it/s]
# 20it [00:00, 20.56it/s]
# 20it [00:00, 20.14it/s]
# 20it [00:00, 21.01it/s]
# 20it [00:01, 17.90it/s]
# 20it [00:01, 19.74it/s]
# 20it [00:01, 19.08it/s]
# 20it [00:01, 19.82it/s]
# 20it [00:01, 19.71it/s]
# 20it [00:01, 19.49it/s]
# 20it [00:01, 19.67it/s]
# 20it [00:01, 19.89it/s]
# 20it [00:01, 19.85it/s]
# 20it [00:01, 19.85it/s]
# 20it [00:00, 20.35it/s]
# 20it [00:00, 20.11it/s]
# 20it [00:00, 20.59it/s]
# 20it [00:00, 21.20it/s]
# 20it [00:01, 19.47it/s]
# 20it [00:00, 20.19it/s]
# 20it [00:00, 20.62it/s]
# 20it [00:00, 20.40it/s]
# 20it [00:00, 20.29it/s]
# 20it [00:00, 20.49it/s]
# 20it [00:00, 20.43it/s]
# 20it [00:00, 20.24it/s]
# 20it [00:00, 20.08it/s]
# 20it [00:00, 20.48it/s]
# 20it [00:01, 19.65it/s]
# 20it [00:01, 19.86it/s]
# 20it [00:01, 19.52it/s]
# 20it [00:01, 19.54it/s]
# 20it [00:01, 19.74it/s]
# 20it [00:00, 20.02it/s]
# 20it [00:00, 21.09it/s]
# 20it [00:00, 20.58it/s]
# 20it [00:01, 19.71it/s]
# 20it [00:00, 20.92it/s]
# 20it [00:00, 20.44it/s]
# 20it [00:00, 20.11it/s]
# 20it [00:00, 20.09it/s]
# 20it [00:01, 19.74it/s]
# 20it [00:00, 20.99it/s]
# 20it [00:01, 19.93it/s]
# 20it [00:00, 20.17it/s]
# 20it [00:00, 20.27it/s]
# 20it [00:00, 20.28it/s]
# 20it [00:00, 20.04it/s]
# 20it [00:01, 19.70it/s]
# 20it [00:01, 19.45it/s]
# 20it [00:01, 20.00it/s]
# 20it [00:00, 20.01it/s]
# 20it [00:00, 20.31it/s]
# 20it [00:01, 19.54it/s]
# 20it [00:01, 19.91it/s]
# 20it [00:00, 20.23it/s]
# 20it [00:01, 19.71it/s]
# 20it [00:01, 19.87it/s]
# 20it [00:00, 20.18it/s]
# 20it [00:01, 19.88it/s]
# 20it [00:01, 19.48it/s]
# 20it [00:00, 20.22it/s]
# 20it [00:01, 19.07it/s]
# 20it [00:01, 19.41it/s]
# 20it [00:01, 19.77it/s]
# 20it [00:01, 19.90it/s]
# 20it [00:01, 19.75it/s]
# 20it [00:00, 20.28it/s]
# 20it [00:01, 19.87it/s]
# 20it [00:00, 20.12it/s]
# 20it [00:01, 19.76it/s]
# 20it [00:01, 19.69it/s]
# 20it [00:00, 20.32it/s]
# 20it [00:00, 20.26it/s]
# 20it [00:01, 19.38it/s]
# 20it [00:01, 19.86it/s]
# 20it [00:01, 19.85it/s]
# 20it [00:00, 20.23it/s]
# 20it [00:00, 20.61it/s]
# 20it [00:00, 21.59it/s]
# 20it [00:01, 19.99it/s]
# 20it [00:01, 19.61it/s]
# 20it [00:01, 19.41it/s]
# 20it [00:00, 20.69it/s]
# 20it [00:00, 20.07it/s]
# 20it [00:00, 20.79it/s]
# 20it [00:01, 19.73it/s]
# 20it [00:00, 20.40it/s]
# 20it [00:01, 19.81it/s]
# 20it [00:00, 20.36it/s]
# 20it [00:01, 19.74it/s]
# 20it [00:01, 19.81it/s]
# 20it [00:00, 20.31it/s]
# 20it [00:01, 19.80it/s]
# 20it [00:01, 19.74it/s]
# 20it [00:00, 20.34it/s]
# 20it [00:01, 19.40it/s]
# 20it [00:00, 20.33it/s]
# 20it [00:01, 18.90it/s]
# 20it [00:01, 19.56it/s]
# 20it [00:01, 19.86it/s]
# 20it [00:00, 21.18it/s]
# 20it [00:01, 18.93it/s]
# 20it [00:01, 19.22it/s]
# 20it [00:00, 20.39it/s]
# 20it [00:01, 19.45it/s]
# 20it [00:01, 17.90it/s]
# 20it [00:01, 19.47it/s]
# 20it [00:00, 20.41it/s]
# 20it [00:01, 19.89it/s]
# 20it [00:01, 19.89it/s]
# 20it [00:01, 18.14it/s]
# 20it [00:01, 19.68it/s]
# 20it [00:01, 19.66it/s]
# 20it [00:01, 19.42it/s]
# 20it [00:00, 20.27it/s]
# 20it [00:00, 20.31it/s]
# 20it [00:00, 20.58it/s]
# 20it [00:01, 18.76it/s]
# 20it [00:01, 19.64it/s]
# 20it [00:00, 20.41it/s]
# 20it [00:00, 20.24it/s]
# 20it [00:01, 19.59it/s]
# 20it [00:00, 20.38it/s]
# 20it [00:01, 19.90it/s]
# 20it [00:00, 20.00it/s]
# 20it [00:01, 19.72it/s]
# 20it [00:01, 19.09it/s]
# 20it [00:01, 19.34it/s]
# 20it [00:01, 19.26it/s]
# 20it [00:01, 19.23it/s]
# 20it [00:00, 20.69it/s]
# 20it [00:00, 20.09it/s]
# 20it [00:00, 21.02it/s]
# 20it [00:01, 19.41it/s]
# 20it [00:01, 19.01it/s]
# 20it [00:00, 20.17it/s]
# 20it [00:00, 20.02it/s]
# 20it [00:00, 20.15it/s]
# 20it [00:01, 17.84it/s]
# 20it [00:00, 20.46it/s]
# 20it [00:00, 20.53it/s]
# 20it [00:00, 20.62it/s]
# 20it [00:00, 20.79it/s]
# 20it [00:00, 20.17it/s]
# 20it [00:01, 19.62it/s]
# 20it [00:00, 20.49it/s]
# 20it [00:01, 19.93it/s]
# 20it [00:01, 19.36it/s]
# 20it [00:01, 18.13it/s]
# 20it [00:01, 19.31it/s]
# 20it [00:00, 20.35it/s]
# 20it [00:00, 20.70it/s]
# 20it [00:00, 20.51it/s]
# 20it [00:01, 19.19it/s]
# 20it [00:01, 17.73it/s]
# 20it [00:00, 20.69it/s]
# 20it [00:01, 19.83it/s]
# 20it [00:00, 20.27it/s]
# 20it [00:00, 20.36it/s]
# 20it [00:01, 17.72it/s]
# 20it [00:00, 20.48it/s]
# 20it [00:00, 20.31it/s]
# 20it [00:00, 20.34it/s]
# 20it [00:00, 20.18it/s]
# 20it [00:01, 19.60it/s]
# 20it [00:01, 19.82it/s]
# 20it [00:00, 20.09it/s]
# 20it [00:00, 20.58it/s]
# 20it [00:00, 21.33it/s]
# 20it [00:00, 20.68it/s]
# 20it [00:00, 21.16it/s]
# 20it [00:00, 20.71it/s]
# 20it [00:00, 20.91it/s]
# 20it [00:01, 19.95it/s]
# 20it [00:00, 20.19it/s]
# 20it [00:01, 19.84it/s]
# 20it [00:00, 20.88it/s]
# 20it [00:01, 19.84it/s]
# 20it [00:01, 19.80it/s]
# 20it [00:01, 19.85it/s]
# 20it [00:00, 20.62it/s]
# 20it [00:01, 17.49it/s]
# 20it [00:01, 19.69it/s]
# 20it [00:01, 19.92it/s]
# 20it [00:00, 20.19it/s]
# 20it [00:00, 20.05it/s]
# 20it [00:00, 20.15it/s]
# 20it [00:00, 20.80it/s]
# 20it [00:00, 20.26it/s]
# 20it [00:00, 20.42it/s]
# 20it [00:00, 21.05it/s]
# 20it [00:01, 19.83it/s]
# 20it [00:01, 19.54it/s]
# 20it [00:00, 20.17it/s]
# 20it [00:00, 20.05it/s]
# 20it [00:00, 20.49it/s]
# 20it [00:01, 19.79it/s]
# 20it [00:01, 17.89it/s]
# 20it [00:00, 20.89it/s]
# 20it [00:00, 20.13it/s]
# 20it [00:00, 20.87it/s]
# 20it [00:01, 19.99it/s]
# 20it [00:01, 19.60it/s]
# 20it [00:01, 17.89it/s]
# 20it [00:00, 20.38it/s]
# 20it [00:00, 20.40it/s]
# 20it [00:01, 19.84it/s]
# 20it [00:01, 17.52it/s]
# 20it [00:01, 17.44it/s]
# 20it [00:00, 20.28it/s]
# 20it [00:00, 20.26it/s]
# 20it [00:01, 19.86it/s]
# 20it [00:00, 20.81it/s]
# 20it [00:01, 17.55it/s]
# 20it [00:00, 20.12it/s]
# 20it [00:00, 20.43it/s]
# 20it [00:01, 19.90it/s]
# 20it [00:00, 20.29it/s]
# 20it [00:01, 17.64it/s]
# 20it [00:00, 21.00it/s]
# 20it [00:00, 20.42it/s]
# 20it [00:01, 12.10it/s]
# 20it [00:01, 16.74it/s]
# 20it [00:01, 11.20it/s]
# 20it [00:00, 20.22it/s]
# 20it [00:01, 11.01it/s]
# 20it [00:01, 19.70it/s]
# 20it [00:01, 15.49it/s]
# 20it [00:01, 15.04it/s]
# 20it [00:01, 13.41it/s]
# 20it [00:01, 19.02it/s]
# 20it [00:01, 19.60it/s]
# 20it [00:01, 18.05it/s]
# 20it [00:01, 11.69it/s]
# 20it [00:01, 19.27it/s]
# 20it [00:01, 14.43it/s]
# 20it [00:01, 15.29it/s]
# 20it [00:01, 16.06it/s]
# 20it [00:01, 18.72it/s]
# 20it [00:01, 15.81it/s]
# 20it [00:01, 14.80it/s]
# 20it [00:01, 15.81it/s]
# 20it [00:01, 16.71it/s]
# 20it [00:01, 18.06it/s]
# 20it [00:01, 16.27it/s]
# 20it [00:01, 15.23it/s]
# 20it [00:01, 16.76it/s]
# 20it [00:01, 19.45it/s]
# 20it [00:01, 15.52it/s]
# 20it [00:01, 15.30it/s]
# 20it [00:01, 16.98it/s]
# 20it [00:01, 19.70it/s]
# 20it [00:01, 17.61it/s]
# 20it [00:01, 14.26it/s]
# 20it [00:01, 17.84it/s]
# 20it [00:01, 15.21it/s]
# 20it [00:01, 14.44it/s]
# 20it [00:01, 17.48it/s]
# 20it [00:01, 19.25it/s]
# 20it [00:01, 16.58it/s]
# 20it [00:01, 16.10it/s]
# 20it [00:01, 15.92it/s]
# 20it [00:01, 16.67it/s]
# 20it [00:01, 19.45it/s]
# 20it [00:01, 17.57it/s]
# 20it [00:01, 13.12it/s]
# 20it [00:01, 19.76it/s]
# 20it [00:01, 16.25it/s]
# 20it [00:01, 14.31it/s]
# 20it [00:01, 16.63it/s]
# 20it [00:01, 16.83it/s]
# 20it [00:01, 17.79it/s]
# 20it [00:01, 13.21it/s]
# 20it [00:01, 16.53it/s]
# 20it [00:01, 17.25it/s]
# 20it [00:01, 18.21it/s]
# 20it [00:01, 14.33it/s]
# 20it [00:01, 17.20it/s]
# 20it [00:01, 18.49it/s]
# 20it [00:01, 13.59it/s]
# 20it [00:01, 13.49it/s]
# 20it [00:01, 16.49it/s]
# 20it [00:01, 19.63it/s]
# 20it [00:01, 15.26it/s]
# 20it [00:01, 18.93it/s]
# 20it [00:01, 11.77it/s]
# 20it [00:01, 17.75it/s]
# 20it [00:01, 15.82it/s]
# 20it [00:01, 13.74it/s]
# 20it [00:01, 16.88it/s]
# 20it [00:01, 18.17it/s]
# 20it [00:01, 16.77it/s]
# 20it [00:01, 15.48it/s]
# 20it [00:01, 14.28it/s]
# 20it [00:01, 18.21it/s]
# 20it [00:01, 16.22it/s]
# 20it [00:01, 16.88it/s]
# 20it [00:01, 12.80it/s]
# 20it [00:01, 16.85it/s]
# 20it [00:01, 17.26it/s]
# 20it [00:01, 13.29it/s]
# 20it [00:01, 15.16it/s]
# 20it [00:01, 18.26it/s]
# 20it [00:00, 20.38it/s]
# 20it [00:01, 19.53it/s]
# 20it [00:01, 14.75it/s]
# 20it [00:01, 19.13it/s]
# 20it [00:01, 18.62it/s]
# 20it [00:00, 20.04it/s]
# 20it [00:01, 16.83it/s]
# 20it [00:01, 11.89it/s]
# 20it [00:01, 17.11it/s]
# 20it [00:01, 12.04it/s]
# 20it [00:01, 18.67it/s]
# 20it [00:01, 10.26it/s]
# 20it [00:01, 17.11it/s]
# 20it [00:01, 12.46it/s]
# 20it [00:01, 18.47it/s]
# 20it [00:01, 18.88it/s]
# 20it [00:01, 19.28it/s]
# 20it [00:01, 19.42it/s]
# 20it [00:01, 14.73it/s]
# 20it [00:01, 18.30it/s]
# 20it [00:01, 11.24it/s]
# 20it [00:01, 19.83it/s]
# 20it [00:01, 11.56it/s]
# 20it [00:01, 17.98it/s]
# 20it [00:01, 10.46it/s]
# 20it [00:01, 18.87it/s]
# 20it [00:01, 10.57it/s]
# 20it [00:01, 19.14it/s]
# 20it [00:01, 19.47it/s]
# 20it [00:01, 19.96it/s]
# 20it [00:01, 18.52it/s]
# 20it [00:01, 18.27it/s]
# 20it [00:01, 16.33it/s]
# 20it [00:01, 17.15it/s]
# 20it [00:01, 19.16it/s]
# 20it [00:01, 16.49it/s]
# 20it [00:01, 18.75it/s]
# 20it [00:01, 19.03it/s]
# 20it [00:00, 20.22it/s]
# 20it [00:01, 19.43it/s]
# 20it [00:01, 19.21it/s]
# 20it [00:01, 18.10it/s]
# 20it [00:01, 14.03it/s]
# 20it [00:01, 18.92it/s]
# 20it [00:01, 19.76it/s]
# 20it [00:01, 17.50it/s]
# 20it [00:01, 18.25it/s]
# 20it [00:01, 15.83it/s]
# 20it [00:01, 18.40it/s]
# 20it [00:01, 19.08it/s]
# 20it [00:01, 14.42it/s]
# 20it [00:01, 18.61it/s]
# 20it [00:01, 12.92it/s]
# 20it [00:01, 18.30it/s]
# 20it [00:01, 18.67it/s]
# 20it [00:01, 16.81it/s]
# 20it [00:01, 18.93it/s]
# 20it [00:01, 16.25it/s]
# 20it [00:01, 18.53it/s]
# 20it [00:01, 13.78it/s]
# 20it [00:01, 18.46it/s]
# 20it [00:01, 17.10it/s]
# 20it [00:01, 16.49it/s]
# 20it [00:01, 18.02it/s]
# 20it [00:01, 18.23it/s]
# 20it [00:01, 16.50it/s]
# 20it [00:01, 18.37it/s]
# 20it [00:01, 10.65it/s]
# 20it [00:01, 13.94it/s]
# 20it [00:00, 20.41it/s]
# 20it [00:00, 20.51it/s]
# 20it [00:01, 15.99it/s]
# 20it [00:01, 11.83it/s]
# 20it [00:01, 17.87it/s]
# 20it [00:01, 17.48it/s]
# 20it [00:00, 20.26it/s]
# 20it [00:01, 19.38it/s]
# 20it [00:01, 19.52it/s]
# 20it [00:01, 18.76it/s]
# 20it [00:01, 11.17it/s]
# 20it [00:01, 18.34it/s]
# 20it [00:01, 12.16it/s]
# 20it [00:01, 18.79it/s]
# 20it [00:01, 11.23it/s]
# 20it [00:01, 19.15it/s]
# 20it [00:01, 11.78it/s]
# 20it [00:01, 13.23it/s]
# 20it [00:01, 12.41it/s]
# 20it [00:01, 17.94it/s]
# 20it [00:01, 12.84it/s]
# 20it [00:01, 14.72it/s]
# 20it [00:01, 11.13it/s]
# 20it [00:01, 18.79it/s]
# 20it [00:00, 20.20it/s]
# 20it [00:00, 20.49it/s]
# 20it [00:01, 19.78it/s]
# 20it [00:01, 12.97it/s]
# 20it [00:01, 19.07it/s]
# 20it [00:01, 12.49it/s]
# 20it [00:01, 15.53it/s]
# 20it [00:00, 20.05it/s]
# 20it [00:01, 19.79it/s]
# 20it [00:01, 16.59it/s]
# 20it [00:01, 17.93it/s]
# 20it [00:01, 19.92it/s]
# 20it [00:01, 18.10it/s]
# 20it [00:01, 19.17it/s]
# 20it [00:01, 19.34it/s]
# 20it [00:01, 17.19it/s]
# 20it [00:01, 15.46it/s]
# 20it [00:01, 17.25it/s]
# 20it [00:01, 16.84it/s]
# 20it [00:01, 19.65it/s]
# 20it [00:01, 19.75it/s]
# 20it [00:01, 18.39it/s]
# 20it [00:01, 19.02it/s]
# 20it [00:01, 18.50it/s]
# 20it [00:01, 11.18it/s]
# 20it [00:01, 14.29it/s]
# 20it [00:01, 16.29it/s]
# 20it [00:01, 18.46it/s]
# 20it [00:01, 19.04it/s]
# 20it [00:01, 15.37it/s]
# 20it [00:01, 14.91it/s]
# 20it [00:01, 19.47it/s]
# 20it [00:01, 13.60it/s]
# 20it [00:01, 14.22it/s]
# 20it [00:01, 18.33it/s]
# 20it [00:01, 17.46it/s]
# 20it [00:01, 19.28it/s]
# 20it [00:01, 14.98it/s]
# 20it [00:00, 20.01it/s]
# 20it [00:01, 18.12it/s]
# 20it [00:01, 18.07it/s]
# 20it [00:01, 11.42it/s]
# 20it [00:01, 18.04it/s]
# 20it [00:01, 19.61it/s]
# 20it [00:01, 18.76it/s]
# 20it [00:00, 20.01it/s]
# 20it [00:00, 20.67it/s]
# 20it [00:01, 19.53it/s]
# 20it [00:00, 20.21it/s]
# 20it [00:01, 19.84it/s]
# ...
# 20it [00:00, 21.16it/s]
# 20it [00:01, 17.81it/s]
# 20it [00:00, 21.37it/s]
# 20it [00:00, 20.11it/s]
# 20it [00:00, 20.63it/s]
# 20it [00:01, 19.77it/s]
# 20it [00:01, 17.66it/s]
# 20it [00:01, 18.04it/s]
# 20it [00:00, 20.48it/s]
# 20it [00:01, 19.93it/s]
# 20it [00:01, 17.77it/s]
# 20it [00:00, 20.27it/s]
# 20it [00:00, 20.04it/s]
# 20it [00:01, 19.55it/s]
# 20it [00:00, 20.46it/s]
# 20it [00:00, 21.19it/s]
# 20it [00:01, 19.76it/s]
# 20it [00:01, 19.74it/s]
# 20it [00:00, 20.26it/s]
# 20it [00:00, 20.53it/s]
# 20it [00:00, 20.89it/s]
# 20it [00:01, 18.09it/s]
# 20it [00:00, 20.08it/s]
# 20it [00:00, 20.01it/s]
# 20it [00:01, 17.91it/s]
# 20it [00:01, 19.99it/s]
# 20it [00:01, 19.54it/s]
# 20it [00:01, 19.81it/s]
# 20it [00:00, 21.04it/s]
# 20it [00:01, 19.75it/s]
# 20it [00:01, 17.90it/s]
# 20it [00:01, 17.51it/s]
# 20it [00:00, 20.09it/s]
# 20it [00:00, 20.32it/s]
# 20it [00:01, 17.89it/s]
# 20it [00:00, 20.79it/s]
# 20it [00:01, 19.15it/s]
# 20it [00:01, 17.52it/s]
# 20it [00:00, 20.34it/s]
# 20it [00:01, 17.81it/s]
# 20it [00:01, 18.96it/s]
# 20it [00:01, 19.71it/s]
# 20it [00:01, 19.09it/s]
# 20it [00:01, 18.87it/s]
# 20it [00:00, 20.05it/s]
# 20it [00:00, 20.16it/s]
# 20it [00:00, 20.17it/s]
# 20it [00:01, 19.92it/s]
# 20it [00:01, 17.73it/s]
# 20it [00:01, 17.66it/s]
# 20it [00:00, 20.41it/s]
# 20it [00:00, 20.20it/s]
# 20it [00:00, 20.02it/s]
# 20it [00:00, 20.30it/s]
# 20it [00:00, 20.29it/s]
# 20it [00:01, 19.82it/s]
# 20it [00:01, 19.56it/s]
# 20it [00:01, 19.60it/s]
# 20it [00:00, 20.94it/s]
# 20it [00:01, 17.92it/s]
# 20it [00:01, 19.03it/s]
# 20it [00:01, 18.33it/s]
# 20it [00:00, 20.37it/s]
# 20it [00:01, 19.27it/s]
# 20it [00:00, 20.22it/s]
# 20it [00:00, 20.96it/s]
# 20it [00:01, 19.33it/s]
# 20it [00:01, 19.42it/s]
# 20it [00:01, 18.04it/s]
# 20it [00:00, 20.40it/s]
# 20it [00:00, 20.30it/s]
# 20it [00:01, 19.78it/s]
# 20it [00:01, 17.56it/s]
# 20it [00:01, 18.03it/s]
# 20it [00:01, 18.17it/s]
# 20it [00:01, 19.63it/s]
# 20it [00:00, 20.08it/s]
# 20it [00:01, 17.81it/s]
# 20it [00:01, 17.55it/s]
# 20it [00:01, 17.80it/s]
# 20it [00:01, 17.72it/s]
# 20it [00:00, 20.90it/s]
# 20it [00:00, 20.85it/s]
# 20it [00:00, 20.28it/s]
# 20it [00:01, 19.80it/s]
# 20it [00:00, 20.39it/s]
# 20it [00:01, 17.94it/s]
# 20it [00:01, 18.06it/s]
# 20it [00:00, 20.16it/s]
# 20it [00:00, 20.50it/s]
# 20it [00:01, 19.79it/s]
# 20it [00:01, 17.94it/s]
# 20it [00:01, 19.17it/s]
# 20it [00:01, 19.94it/s]
# 20it [00:00, 20.61it/s]
# 20it [00:01, 19.50it/s]
# 20it [00:01, 19.78it/s]
# 20it [00:00, 20.06it/s]
# 20it [00:00, 20.26it/s]
# 20it [00:01, 18.09it/s]
# 20it [00:01, 17.84it/s]
# 20it [00:00, 20.26it/s]
# 20it [00:01, 19.70it/s]
# 20it [00:00, 20.05it/s]
# 20it [00:01, 19.80it/s]
# 20it [00:01, 19.57it/s]
# 20it [00:01, 19.41it/s]
# 20it [00:01, 19.97it/s]
# 20it [00:01, 19.80it/s]
# 20it [00:00, 20.24it/s]
# 20it [00:00, 20.39it/s]
# 20it [00:00, 20.05it/s]
# 20it [00:01, 17.96it/s]
# 20it [00:01, 19.85it/s]
# 20it [00:01, 19.43it/s]
# 20it [00:00, 20.75it/s]
# 20it [00:01, 18.46it/s]
# 20it [00:00, 20.27it/s]
# 20it [00:01, 17.50it/s]
# 20it [00:01, 17.98it/s]
# 20it [00:01, 19.18it/s]
# 20it [00:00, 20.19it/s]
# 20it [00:00, 21.20it/s]
# 20it [00:01, 17.91it/s]
# 20it [00:00, 20.21it/s]
# 20it [00:00, 20.31it/s]
# 20it [00:01, 19.51it/s]
# 20it [00:00, 20.18it/s]
# 20it [00:01, 17.47it/s]
# 20it [00:00, 20.29it/s]
# 20it [00:00, 20.37it/s]
# 20it [00:01, 19.87it/s]
# 20it [00:00, 20.43it/s]
# 20it [00:00, 20.30it/s]
# 20it [00:00, 20.19it/s]
# 20it [00:00, 20.49it/s]
# 20it [00:01, 17.75it/s]
# 20it [00:00, 20.72it/s]
# 20it [00:01, 19.62it/s]
# 20it [00:01, 17.43it/s]
# 20it [00:01, 19.70it/s]
# 20it [00:00, 20.47it/s]
# 20it [00:01, 18.16it/s]
# 20it [00:00, 20.44it/s]
# 20it [00:01, 19.94it/s]
# 20it [00:00, 20.26it/s]
# 20it [00:00, 20.65it/s]
# 20it [00:01, 19.20it/s]
# 20it [00:00, 20.36it/s]
# 20it [00:00, 20.10it/s]
# 20it [00:00, 20.70it/s]
# 20it [00:00, 20.00it/s]
# 20it [00:00, 20.16it/s]
# 20it [00:00, 20.93it/s]
# 20it [00:01, 19.69it/s]
# 20it [00:01, 19.75it/s]
# 20it [00:01, 19.94it/s]
# 20it [00:01, 17.58it/s]
# 20it [00:00, 20.12it/s]
# 20it [00:01, 17.91it/s]
# 20it [00:00, 20.10it/s]
# 20it [00:01, 19.59it/s]
# 20it [00:01, 19.68it/s]
# 20it [00:00, 20.64it/s]
# 20it [00:00, 20.54it/s]
# 20it [00:00, 20.12it/s]
# 20it [00:01, 17.86it/s]
# 20it [00:01, 17.91it/s]
# 20it [00:01, 19.84it/s]
# 20it [00:00, 20.16it/s]
# 20it [00:01, 19.91it/s]
# 20it [00:00, 20.27it/s]
# 20it [00:01, 17.61it/s]
# 20it [00:00, 20.25it/s]
# 20it [00:00, 20.35it/s]
# 20it [00:01, 18.09it/s]
# 20it [00:00, 20.43it/s]
# 20it [00:01, 18.08it/s]
# 20it [00:01, 19.70it/s]
# 20it [00:01, 17.38it/s]
# 20it [00:01, 19.57it/s]
# 20it [00:01, 17.60it/s]
# 20it [00:00, 20.86it/s]
# 20it [00:01, 17.27it/s]
# 20it [00:01, 17.71it/s]
# 20it [00:01, 19.77it/s]
# 20it [00:00, 20.44it/s]
# 20it [00:01, 19.98it/s]
# 20it [00:01, 17.84it/s]
# 20it [00:01, 17.46it/s]
# 20it [00:01, 18.01it/s]
# 20it [00:01, 18.14it/s]
# 20it [00:01, 17.87it/s]
# 20it [00:00, 21.13it/s]
# 20it [00:01, 17.26it/s]
# 20it [00:01, 19.91it/s]
# 20it [00:01, 19.77it/s]
# 20it [00:00, 20.48it/s]

# %%
'''Proof of success - print all mutations 
from the json files generated above'''

import os
import json

mutations = {}
#Walk recursively down the 'files' file tree
for path,dirs,files in os.walk('files/'):
    #Look only at files
    for f in files:
        #Only look at files that are non-checkpoint .json
        if '.json' in f and not '-checkpoint' in f:
            #Load the json
            data = json.load(open(os.path.join(path,f)))
            '''
            JSON is basically a nested dictionary structure.
            Sometimes the dicts map to dicts of lists.
            So if we know the structure (which we can get
            by inspecting the json file manually) we can drill
            down to the information we want:
            '''
            print('Seq Index: ', path.split('/')[-1], '(Mutations)') 
            print(data[0]['alignedGeneSequences'][0]['mutations'])
# Out:
# Seq Index:  9 (Mutations)
# [{'consensus': 'T', 'position': 12, 'AAs': 'S', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'D', 'position': 30, 'AAs': 'N', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': True}, {'consensus': 'I', 'position': 62, 'AAs': 'V', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'L', 'position': 63, 'AAs': 'P', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'H', 'position': 69, 'AAs': 'Q', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}]
# Seq Index:  0 (Mutations)
# [{'consensus': 'T', 'position': 12, 'AAs': 'P', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'K', 'position': 14, 'AAs': 'R', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'E', 'position': 35, 'AAs': 'D', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'N', 'position': 37, 'AAs': 'E', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'R', 'position': 57, 'AAs': 'KR', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'I', 'position': 62, 'AAs': 'IV', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'L', 'position': 63, 'AAs': 'P', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'C', 'position': 67, 'AAs': 'Y', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'I', 'position': 72, 'AAs': 'V', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'V', 'position': 77, 'AAs': 'I', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'I', 'position': 93, 'AAs': 'L', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}]
# Seq Index:  7 (Mutations)
# [{'consensus': 'T', 'position': 12, 'AAs': 'S', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'L', 'position': 19, 'AAs': 'V', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'D', 'position': 30, 'AAs': 'N', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': True}, {'consensus': 'L', 'position': 33, 'AAs': 'F', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'K', 'position': 45, 'AAs': 'R', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'I', 'position': 54, 'AAs': 'L', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'R', 'position': 57, 'AAs': 'K', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'L', 'position': 63, 'AAs': 'P', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'A', 'position': 71, 'AAs': 'T', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'V', 'position': 77, 'AAs': 'I', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'I', 'position': 85, 'AAs': 'V', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'N', 'position': 88, 'AAs': 'D', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'I', 'position': 93, 'AAs': 'L', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}]
# Seq Index:  6 (Mutations)
# [{'consensus': 'T', 'position': 12, 'AAs': 'S', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'R', 'position': 41, 'AAs': 'K', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'K', 'position': 43, 'AAs': 'R', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'K', 'position': 45, 'AAs': 'KR', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'L', 'position': 63, 'AAs': 'P', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'I', 'position': 64, 'AAs': 'V', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'V', 'position': 77, 'AAs': 'I', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'I', 'position': 93, 'AAs': 'L', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}]
# Seq Index:  1 (Mutations)
# [{'consensus': 'T', 'position': 12, 'AAs': 'A', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'E', 'position': 35, 'AAs': 'D', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'N', 'position': 37, 'AAs': 'E', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'M', 'position': 46, 'AAs': 'I', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': True}, {'consensus': 'L', 'position': 63, 'AAs': 'P', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'A', 'position': 71, 'AAs': 'V', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'G', 'position': 73, 'AAs': 'S', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': True}, {'consensus': 'V', 'position': 77, 'AAs': 'I', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'L', 'position': 90, 'AAs': 'M', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'I', 'position': 93, 'AAs': 'L', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}]
# Seq Index:  8 (Mutations)
# [{'consensus': 'T', 'position': 12, 'AAs': 'S', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'L', 'position': 19, 'AAs': 'V', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'E', 'position': 35, 'AAs': 'D', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'N', 'position': 37, 'AAs': 'T', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'L', 'position': 63, 'AAs': 'E', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'I', 'position': 64, 'AAs': 'IL', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'E', 'position': 65, 'AAs': 'DE', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}]
# Seq Index:  4 (Mutations)
# [{'consensus': 'T', 'position': 12, 'AAs': 'A', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'I', 'position': 13, 'AAs': 'V', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'N', 'position': 37, 'AAs': 'T', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'I', 'position': 62, 'AAs': 'V', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'L', 'position': 63, 'AAs': 'P', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}]
# Seq Index:  3 (Mutations)
# [{'consensus': 'T', 'position': 12, 'AAs': 'A', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'K', 'position': 14, 'AAs': 'R', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'E', 'position': 35, 'AAs': 'D', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'R', 'position': 41, 'AAs': 'K', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'D', 'position': 60, 'AAs': 'E', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'Q', 'position': 61, 'AAs': 'E', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'L', 'position': 63, 'AAs': 'P', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}]
# Seq Index:  2 (Mutations)
# [{'consensus': 'T', 'position': 12, 'AAs': 'A', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'I', 'position': 15, 'AAs': 'V', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'E', 'position': 35, 'AAs': 'D', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'N', 'position': 37, 'AAs': 'S', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'R', 'position': 41, 'AAs': 'K', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'I', 'position': 64, 'AAs': 'V', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}]
# Seq Index:  5 (Mutations)
# [{'consensus': 'T', 'position': 12, 'AAs': 'S', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'K', 'position': 43, 'AAs': 'R', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'R', 'position': 57, 'AAs': 'K', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'I', 'position': 62, 'AAs': 'V', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'L', 'position': 63, 'AAs': 'P', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'A', 'position': 71, 'AAs': 'T', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}, {'consensus': 'I', 'position': 93, 'AAs': 'L', 'isInsertion': False, 'isDeletion': False, 'isApobecDRM': False}]

# %%
'''
And that's it! Now you can take the mutations list, 
and the indices of each mutation, and find shared
mutations across the bad performers.
'''

# %%
jsons = []
for path,dirs,files in os.walk('files/'):
    #Look only at files
    for f in files:
        #Only look at files that are non-checkpoint .json
        if '.json' in f and not '-checkpoint' in f:
            #Load the json
            data = json.load(open(os.path.join(path,f)))
            '''
            JSON is basically a nested dictionary structure.
            Sometimes the dicts map to dicts of lists.
            So if we know the structure (which we can get
            by inspecting the json file manually) we can drill
            down to the information we want:
            '''
            
            jsons.append(data)

# %%
#muts => [0]['alignedGeneSequences'][0]['mutations']
res = jsons[0][0]
res.keys()
# Out:
# dict_keys(['inputSequence', 'subtypeText', 'validationResults', 'alignedGeneSequences', 'drugResistance'])

# %%
res['drugResistance'][0]['drugScores']
# Out:
# 8

# %%
jsons[0][0]['alignedGeneSequences'][0]['mutations']
# Out:
# [{'consensus': 'T',
#   'position': 12,
#   'AAs': 'S',
#   'isInsertion': False,
#   'isDeletion': False,
#   'isApobecDRM': False},
#  {'consensus': 'D',
#   'position': 30,
#   'AAs': 'N',
#   'isInsertion': False,
#   'isDeletion': False,
#   'isApobecDRM': True},
#  {'consensus': 'I',
#   'position': 62,
#   'AAs': 'V',
#   'isInsertion': False,
#   'isDeletion': False,
#   'isApobecDRM': False},
#  {'consensus': 'L',
#   'position': 63,
#   'AAs': 'P',
#   'isInsertion': False,
#   'isDeletion': False,
#   'isApobecDRM': False},
#  {'consensus': 'H',
#   'position': 69,
#   'AAs': 'Q',
#   'isInsertion': False,
#   'isDeletion': False,
#   'isApobecDRM': False}]

# %%
# Out:
# mkdir: files/0: File exists
# 20it [00:00, 20.90it/s]
# mkdir: files/1: File exists
# 20it [00:01, 19.35it/s]
# mkdir: files/2: File exists
# 20it [00:00, 23.91it/s]
# mkdir: files/3: File exists
# 20it [00:00, 21.46it/s]
# mkdir: files/4: File exists
# 20it [00:00, 24.30it/s]
# mkdir: files/5: File exists
# 20it [00:00, 23.64it/s]
# mkdir: files/6: File exists
# 20it [00:00, 21.06it/s]
# mkdir: files/7: File exists
# 20it [00:00, 21.64it/s]
# mkdir: files/8: File exists
# 20it [00:01, 17.86it/s]
# mkdir: files/9: File exists
# 20it [00:01, 17.98it/s]
# 20it [00:02,  7.96it/s]
# 20it [00:01, 17.14it/s]
# 20it [00:01, 14.38it/s]
# 20it [00:00, 24.55it/s]
# 20it [00:00, 23.38it/s]
# 20it [00:00, 23.62it/s]
# 20it [00:00, 22.82it/s]
# 20it [00:00, 24.08it/s]
# 20it [00:00, 21.31it/s]
# 20it [00:00, 23.20it/s]
# 20it [00:00, 23.22it/s]
# 20it [00:00, 22.50it/s]
# 20it [00:00, 22.34it/s]
# 20it [00:00, 20.73it/s]
# 20it [00:00, 23.09it/s]
# 20it [00:00, 22.17it/s]
# 20it [00:00, 21.87it/s]
# 20it [00:00, 21.60it/s]
# 20it [00:00, 22.34it/s]
# 20it [00:00, 21.96it/s]
# 20it [00:00, 20.35it/s]
# 20it [00:00, 20.22it/s]
# 20it [00:00, 21.50it/s]
# 20it [00:00, 22.83it/s]
# 20it [00:00, 20.48it/s]
# 20it [00:01, 14.14it/s]
# 20it [00:01, 17.84it/s]
# 20it [00:00, 23.07it/s]
# 20it [00:00, 24.41it/s]
# 20it [00:00, 23.18it/s]
# 20it [00:00, 22.39it/s]
# 20it [00:00, 22.29it/s]
# 20it [00:00, 21.78it/s]
# 20it [00:00, 20.21it/s]
# 20it [00:00, 22.11it/s]
# 20it [00:00, 23.01it/s]
# 20it [00:00, 22.61it/s]
# 20it [00:00, 21.74it/s]
# 20it [00:00, 23.11it/s]
# 20it [00:01, 19.58it/s]
# 20it [00:01, 17.53it/s]
# 20it [00:00, 22.84it/s]
# 20it [00:00, 21.78it/s]
# 20it [00:00, 22.11it/s]
# 20it [00:00, 21.81it/s]
# 20it [00:00, 22.67it/s]
# 20it [00:00, 22.73it/s]
# 20it [00:00, 24.04it/s]
# 20it [00:00, 22.71it/s]
# 20it [00:00, 21.84it/s]
# 20it [00:00, 23.46it/s]
# 20it [00:01, 19.94it/s]
# 20it [00:00, 23.57it/s]
# 20it [00:01, 19.94it/s]
# 20it [00:00, 23.59it/s]
# 20it [00:01, 19.58it/s]
# 20it [00:00, 22.29it/s]
# 20it [00:00, 21.48it/s]
# 20it [00:00, 22.27it/s]
# 20it [00:01, 19.82it/s]
# 20it [00:00, 21.54it/s]
# 20it [00:00, 20.71it/s]
# 20it [00:00, 23.44it/s]
# 20it [00:00, 23.15it/s]
# 20it [00:00, 22.60it/s]
# 20it [00:00, 21.10it/s]
# 20it [00:00, 21.91it/s]
# 20it [00:00, 21.44it/s]
# 20it [00:00, 21.79it/s]
# 20it [00:00, 23.11it/s]
# 20it [00:00, 23.16it/s]
# 20it [00:00, 22.60it/s]
# 20it [00:00, 23.08it/s]
# 20it [00:00, 21.63it/s]
# 20it [00:00, 22.20it/s]
# 20it [00:00, 21.95it/s]
# 20it [00:00, 23.14it/s]
# 20it [00:00, 21.17it/s]
# 20it [00:00, 22.40it/s]
# 20it [00:00, 21.13it/s]
# 20it [00:00, 21.64it/s]
# 20it [00:00, 21.82it/s]
# 20it [00:00, 22.26it/s]
# 20it [00:00, 22.58it/s]
# 20it [00:00, 22.50it/s]
# ^C
# Traceback (most recent call last):
#   File "/Users/mgbvox/anaconda3/bin/sierrapy", line 7, in <module>
#     from sierrapy.cmds import main
#   File "/Users/mgbvox/anaconda3/lib/python3.7/site-packages/sierrapy/__init__.py", line 2, in <module>
#     from .sierraclient import VERSION, SierraClient
#   File "/Users/mgbvox/anaconda3/lib/python3.7/site-packages/sierrapy/sierraclient.py", line 7, in <module>
#     from gql import gql, Client
#   File "/Users/mgbvox/anaconda3/lib/python3.7/site-packages/gql/__init__.py", line 1, in <module>
#     from .gql import gql
#   File "/Users/mgbvox/anaconda3/lib/python3.7/site-packages/gql/gql.py", line 2, in <module>
#     from graphql.language.parser import parse
#   File "/Users/mgbvox/anaconda3/lib/python3.7/site-packages/graphql/__init__.py", line 27, in <module>
#     from .graphql import graphql
#   File "/Users/mgbvox/anaconda3/lib/python3.7/site-packages/graphql/graphql.py", line 1, in <module>
#     from .execution import ExecutionResult
#   File "/Users/mgbvox/anaconda3/lib/python3.7/site-packages/graphql/execution/__init__.py", line 21, in <module>
#     from .executor import execute, subscribe
#   File "/Users/mgbvox/anaconda3/lib/python3.7/site-packages/graphql/execution/executor.py", line 11, in <module>
#     from rx import Observable
#   File "/Users/mgbvox/anaconda3/lib/python3.7/site-packages/rx/__init__.py", line 2, in <module>
#     import asyncio
#   File "/Users/mgbvox/anaconda3/lib/python3.7/asyncio/__init__.py", line 42, in <module>
#     from .unix_events import *  # pragma: no cover
#   File "/Users/mgbvox/anaconda3/lib/python3.7/asyncio/unix_events.py", line 22, in <module>
#     from . import selector_events
#   File "/Users/mgbvox/anaconda3/lib/python3.7/asyncio/selector_events.py", line 578, in <module>
#     transports.Transport):
#   File "/Users/mgbvox/anaconda3/lib/python3.7/asyncio/selector_events.py", line 709, in _SelectorTransport
#     def get_write_buffer_size(self):
# KeyboardInterrupt
# 20it [00:00, 22.13it/s]
# 20it [00:00, 22.34it/s]
# 20it [00:00, 23.40it/s]
# 20it [00:00, 21.05it/s]

# %%
# !sierrapy fasta files/pr_fasta.txt -o files/pr_fasta.json
# Out:
#   0%|                                                  | 0/1425 [00:00<?, ?it/s]Traceback (most recent call last):
#   File "/Users/mgbvox/anaconda3/lib/python3.7/site-packages/sierrapy/sierraclient.py", line 77, in execute
#     document, variable_values=variable_values)
#   File "/Users/mgbvox/anaconda3/lib/python3.7/site-packages/gql/client.py", line 50, in execute
#     result = self._get_result(document, *args, **kwargs)
#   File "/Users/mgbvox/anaconda3/lib/python3.7/site-packages/gql/client.py", line 58, in _get_result
#     return self.transport.execute(document, *args, **kwargs)
#   File "/Users/mgbvox/anaconda3/lib/python3.7/site-packages/sierrapy/sierraclient.py", line 37, in execute
#     request.raise_for_status()
#   File "/Users/mgbvox/anaconda3/lib/python3.7/site-packages/requests/models.py", line 940, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 400 Client Error:  for url: https://hivdb.stanford.edu/graphql
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/mgbvox/anaconda3/bin/sierrapy", line 11, in <module>
#     sys.exit(main())
#   File "/Users/mgbvox/anaconda3/lib/python3.7/site-packages/sierrapy/cmds.py", line 9, in main
#     cli(obj={})
#   File "/Users/mgbvox/anaconda3/lib/python3.7/site-packages/click/core.py", line 764, in __call__
#     return self.main(*args, **kwargs)
#   File "/Users/mgbvox/anaconda3/lib/python3.7/site-packages/click/core.py", line 717, in main
#     rv = self.invoke(ctx)
#   File "/Users/mgbvox/anaconda3/lib/python3.7/site-packages/click/core.py", line 1137, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#   File "/Users/mgbvox/anaconda3/lib/python3.7/site-packages/click/core.py", line 956, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#   File "/Users/mgbvox/anaconda3/lib/python3.7/site-packages/click/core.py", line 555, in invoke
#     return callback(*args, **kwargs)
#   File "/Users/mgbvox/anaconda3/lib/python3.7/site-packages/click/decorators.py", line 17, in new_func
#     return f(get_current_context(), *args, **kwargs)
#   File "/Users/mgbvox/anaconda3/lib/python3.7/site-packages/sierrapy/commands/fasta.py", line 29, in fasta
#     result = ctx.obj['CLIENT'].sequence_analysis(sequences, query)
#   File "/Users/mgbvox/anaconda3/lib/python3.7/site-packages/sierrapy/sierraclient.py", line 154, in sequence_analysis
#     return list(self.iter_sequence_analysis(sequences, query, step))
#   File "/Users/mgbvox/anaconda3/lib/python3.7/site-packages/sierrapy/sierraclient.py", line 139, in iter_sequence_analysis
#     for result in self._sequence_analysis(sequences[:step], query):
#   File "/Users/mgbvox/anaconda3/lib/python3.7/site-packages/sierrapy/sierraclient.py", line 106, in _sequence_analysis
#     variable_values={"sequences": sequences})
#   File "/Users/mgbvox/anaconda3/lib/python3.7/site-packages/sierrapy/sierraclient.py", line 87, in execute
#     '\n - '.join(errors))
# sierrapy.sierraclient.ResponseError: Sierra GraphQL webservice returned errors:
#  -
